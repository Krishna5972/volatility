# %%
from sqlalchemy import create_engine
import pandas as pd
from data_extraction import *
from binance_keys import api_key,secret_key
from binance.client import Client
from datetime import datetime,timedelta
from functions import *
from functions_volatile import *
engine = create_engine('sqlite:///CryptoDB.db')
import warnings
warnings.filterwarnings('ignore')

# %%
coin = 'BLZ'
timeframe ='1h'
period = 14
atr1 = 1

str_date = (datetime.now()- timedelta(days=10)).strftime('%b %d,%Y')
end_str = (datetime.now() +  timedelta(days=3)).strftime('%b %d,%Y')
client=Client(api_key,secret_key)

# %%
df=dataextract(coin,str_date,end_str,timeframe,client)
super_df=supertrend(coin,df, period,atr1)
trade_df=create_signal_df(super_df,df,coin,timeframe,atr1,period,100,100)
main_columns = ['TradeOpenTime','signal', 'entry', 'trade',
       'rsi','slowk','percentage','max_log_return', 'min_log_return','ema_81','upper_band', 'lower_band',]
trade_df[main_columns]
# Out:
# Gathering ENJ_1h.csv
# Retrived 250 candlestick data
#          TradeOpenTime signal   entry trade        rsi      slowk  percentage  \
# 2  2023-08-10 16:00:00   Sell  0.2895     L  48.016321  22.555157   -0.001382
# 3  2023-08-11 00:00:00    Buy  0.2899     L  51.011960  32.142857   -0.007244
# 4  2023-08-11 11:00:00   Sell  0.2878     W  38.115003  21.264368    0.002432
# 5  2023-08-11 16:00:00    Buy  0.2871     W  41.118291  31.299332    0.009404
# 6  2023-08-12 13:00:00   Sell  0.2898     L  49.673739  26.470588   -0.002415
# 7  2023-08-12 18:00:00    Buy  0.2905     L  54.836736  54.711955   -0.004131
# 8  2023-08-13 01:00:00   Sell  0.2893     L  45.565416  32.000000   -0.008296
# 9  2023-08-13 04:00:00    Buy  0.2917     W  60.324332  67.207559    0.007199
# 10 2023-08-13 17:00:00   Sell  0.2938     W  58.717382  60.985562    0.003744
# 11 2023-08-14 01:00:00    Buy  0.2927     L  54.564736  83.581560   -0.003416
# 12 2023-08-14 11:00:00   Sell  0.2917     W  44.736282  36.228683    0.007885
# 13 2023-08-14 17:00:00    Buy  0.2894     L  41.192018  37.113468   -0.002764
# 14 2023-08-15 00:00:00   Sell  0.2886     L  38.778758  11.754313   -0.000000
# 15 2023-08-15 06:00:00    Buy  0.2886     L  45.262990  70.663440   -0.009702
# 16 2023-08-15 08:00:00   Sell  0.2858     L  35.358980  36.469622   -0.007348
# 17 2023-08-15 10:00:00    Buy  0.2879     L  46.361002  28.242894   -0.015283
# 18 2023-08-15 14:00:00   Sell  0.2835     W  33.054655  37.063379    0.022575
# 19 2023-08-15 17:00:00    Buy  0.2771     L  28.687037  54.723863   -0.014074
# 20 2023-08-16 01:00:00   Sell  0.2732     W  29.817592  33.796610    0.037335
# 21 2023-08-16 19:00:00    Buy  0.2630     L  36.166329  43.252606   -0.010646
# 22 2023-08-17 09:00:00   Sell  0.2602     L  35.552385  26.711712   -0.000000
# 23 2023-08-17 13:00:00    Buy  0.2602     L  43.215096  49.624681   -0.013067
# 24 2023-08-17 16:00:00   Sell  0.2568     W  36.508195  72.698413    0.063863
# 25 2023-08-17 20:00:00    Buy  0.2404     L  32.836391  53.864968   -1.000000
#
#     max_log_return  min_log_return    ema_81  upper_band  lower_band
# 2         0.005181        0.004491       NaN    0.291529    0.288571
# 3         0.010003        0.010003       NaN    0.290536    0.288064
# 4         0.010076        0.002432       NaN    0.290664    0.287336
# 5         0.020550        0.001393       NaN    0.288686    0.285314
# 6         0.004831        0.002761  0.289568    0.291693    0.289007
# 7         0.004131        0.006196  0.289544    0.291614    0.288986
# 8         0.001037        0.008642  0.289664    0.290543    0.288357
# 9         0.018512        0.003771  0.289730    0.291886    0.289614
# 10        0.019061        0.001702  0.290705    0.295971    0.292629
# 11        0.010591        0.004783  0.290831    0.294021    0.290079
# 12        0.018512        0.002400  0.291431    0.294650    0.291450
# 13        0.005529        0.003110  0.291133    0.290586    0.287214
# 14        0.010395        0.000347  0.290901    0.290550    0.287350
# 15        0.000347        0.010049  0.290427    0.289093    0.286307
# 16        0.004899        0.008048  0.290228    0.288057    0.285043
# 17        0.000695        0.019104  0.290059    0.287971    0.284529
# 18        0.075485        0.000353  0.289623    0.286236    0.282264
# 19        0.006496        0.014796  0.288628    0.279593    0.272707
# 20        0.070644        0.001464  0.286289    0.278407    0.270893
# 21        0.008745        0.026236  0.279123    0.264450    0.257150
# 22        0.030361        0.004228  0.274239    0.263114    0.258486
# 23        0.001922        0.020369  0.272684    0.261736    0.256064
# 24        0.170950        0.002726  0.271675    0.260329    0.254271
# 25        0.020383        0.012063  0.268359    0.246500    0.232000

# %%
volatile_df = get_volatile_dataframe()
volatile_df
# Out:
#                           E             s        o        h        l        c  \
# 179 2023-08-19 08:39:09.602      USDCUSDT  0.99987   1.0003  0.99974  0.99991
# 41  2023-08-19 08:39:10.015    BTCDOMUSDT   1839.5   1843.0   1815.8   1819.0
# 174 2023-08-19 08:39:13.010       TRXUSDT    0.073  0.07364  0.07239  0.07346
# 35  2023-08-19 08:39:08.766  BLUEBIRDUSDT    5.994    6.069    5.929    6.012
# 188 2023-08-19 08:39:04.704       XTZUSDT    0.691    0.705    0.688    0.701
# ..                      ...           ...      ...      ...      ...      ...
# 113 2023-08-19 08:39:13.534       LPTUSDT    6.155    7.378    5.818    7.144
# 137 2023-08-19 08:39:13.526       OXTUSDT  0.05227  0.06842   0.0522  0.06451
# 192 2023-08-19 08:39:14.384       YGGUSDT   0.2158   0.2827   0.2126   0.2592
# 152 2023-08-19 08:39:14.532      RUNEUSDT    1.444    2.052     1.42    1.462
# 37  2023-08-19 08:39:12.464       BLZUSDT  0.08078   0.1214  0.08033  0.11665
#
#       PctRange  Volatility
# 179   0.056015    0.056015
# 41    1.497962    1.497962
# 174   1.726758    1.726758
# 35    2.361275    2.361275
# 188    2.47093    2.470930
# ..         ...         ...
# 113  26.813338   26.813338
# 137  31.072797   31.072797
# 192  32.972719   32.972719
# 152  44.507042   44.507042
# 37   51.126603   51.126603
#
# [197 rows x 8 columns]

# %%
volatile_df = get_volatile_dataframe()

current_trend_coin_idx = -1
found_coin_trend_1 = False
while found_coin_trend_1 == False:
    coin = volatile_df.iloc[current_trend_coin_idx]['s'][:-4]
    print(f'Currently checking gor coin {coin}')
    
    df=dataextract(coin,str_date,end_str,timeframe,client)
    super_df=supertrend(coin,df, period,atr1)
    trade_df=create_signal_df(super_df,df,coin,timeframe,atr1,period,100,100)
    
    current_trend_coin_signal = trade_df.iloc[-1]['signal']
    if current_trend_coin_signal == "Buy":
        if trade_df.iloc[-1]['max_log_return'] > 0.0441:
            print('Missed Buy, looking for another')
            current_trend_coin_idx -= 1
        else:
            print('Take trade')
            found_coin_trend_1 = True
    else:
        if trade_df.iloc[-1]['max_log_return'] > 0.0414:
            print('Missed Sell , looking for another')
            current_trend_coin_idx -= 1        
        else:
            print('Take trade')
            found_coin_trend_1 = True
    print(current_trend_coin_idx)   
    
first_trend_coin = coin
# Out:
# Currently checking gor coin BLZ
# Gathering BLZ_1h.csv
# Retrived 250 candlestick data
# Missed Buy, looking for another
# -2
# Currently checking gor coin RUNE
# Gathering RUNE_1h.csv
# Retrived 250 candlestick data
# Missed Sell , looking for another
# -3
# Currently checking gor coin YGG
# Gathering YGG_1h.csv
# Retrived 250 candlestick data
# Take trade
# -3

# %%
print(f'Found the 1st coin to trade(Ride the trend wave) : {coin}')
# Out:
# Found the 1st coin to trade(Ride the trend wave) : YGG

# %%
current_trend_coin_idx -= 1
found_coin_trend_1 = False
while found_coin_trend_1 == False:
    coin = volatile_df.iloc[current_trend_coin_idx]['s'][:-4]
    print(f'Currently checking gor coin {coin}')
    
    df=dataextract(coin,str_date,end_str,timeframe,client)
    super_df=supertrend(coin,df, period,atr1)
    trade_df=create_signal_df(super_df,df,coin,timeframe,atr1,period,100,100)
    
    current_trend_coin_signal = trade_df.iloc[-1]['signal']
    if current_trend_coin_signal == "Buy":
        if trade_df.iloc[-1]['max_log_return'] > 0.0441:
            print('Missed Buy, looking for another')
            current_trend_coin_idx -= 1
        else:
            print('Take trade')
            found_coin_trend_1 = True
    else:
        if trade_df.iloc[-1]['max_log_return'] > 0.0414:
            print('Missed Sell , looking for another')
            current_trend_coin_idx -= 1        
        else:
            print('Take trade')
            found_coin_trend_1 = True
    print(current_trend_coin_idx) 
print(f'Found the second coin to trade(Ride the trend wave) : {coin}')
second_trend_coin = coin
# Out:
# Currently checking gor coin OXT
# Gathering OXT_1h.csv
# Retrived 190 candlestick data
# Take trade
# -4
# Found the second coin to trade(Ride the trend wave) : OXT

# %%
first_trend_coin , second_trend_coin
# Out:
# ('YGG', 'OXT')

# %%
trade_df[main_columns]
# Out:
#          TradeOpenTime signal    entry       tp trade  close_price        rsi  \
# 2  2023-08-12 14:00:00   Sell  0.07379 -7.30521     L      0.07666  39.988846
# 3  2023-08-12 19:00:00    Buy  0.07666  7.74266     L      0.07427  50.690337
# 4  2023-08-12 22:00:00   Sell  0.07427 -7.35273     L      0.07674  42.405468
# 5  2023-08-13 07:00:00    Buy  0.07674  7.75074     L      0.07598  55.816499
# 6  2023-08-13 10:00:00   Sell  0.07598 -7.52202     W      0.07291  51.742263
# 7  2023-08-14 04:00:00    Buy  0.07291  7.36391     L      0.07138  47.506206
# 8  2023-08-14 09:00:00   Sell  0.07138 -7.06662     L      0.07205  38.922297
# 9  2023-08-14 20:00:00    Buy  0.07205  7.27705     L      0.07016  49.961439
# 10 2023-08-14 22:00:00   Sell  0.07016 -6.94584     W      0.06369  37.766277
# 11 2023-08-15 18:00:00    Buy  0.06369  6.43269     L      0.06185  24.044474
# 12 2023-08-15 21:00:00   Sell  0.06185 -6.12315     W      0.06115  18.481454
# 13 2023-08-16 14:00:00    Buy  0.06115  6.17615     L      0.05943  36.710120
# 14 2023-08-16 16:00:00   Sell  0.05943 -5.88357     L      0.05943  26.802970
# 15 2023-08-17 04:00:00    Buy  0.05943  6.00243     L      0.05826  45.281279
# 16 2023-08-17 10:00:00   Sell  0.05826 -5.76774     W      0.05793  38.950968
# 17 2023-08-17 15:00:00    Buy  0.05793  5.85093     L      0.05047  41.265897
# 18 2023-08-17 17:00:00   Sell  0.05047 -4.99653     L      0.05358  18.314009
# 19 2023-08-18 04:00:00    Buy  0.05358  5.41158     W      0.06223  44.305550
# 20 2023-08-18 19:00:00   Sell  0.06223 -6.16077     L      0.06553  64.289673
# 21 2023-08-18 22:00:00    Buy  0.06553  6.61853     L      0.06356  71.021075
# 22 2023-08-19 04:00:00   Sell  0.06356 -6.29244     W      0.00000  57.408876
#
#         slowk  percentage  max_log_return  min_log_return    ema_81
# 2   16.304242   -0.038894        0.002168        0.050142       NaN
# 3   75.398718   -0.031177       -0.000783        0.034699       NaN
# 4   26.660053   -0.033257        0.011983        0.035277       NaN
# 5   84.261850   -0.009904        0.025541        0.019156       NaN
# 6   45.377879    0.040405        0.074625        0.009476       NaN
# 7   84.210252   -0.020985        0.010424        0.029351       NaN
# 8   23.820043   -0.009386        0.009526        0.022555       NaN
# 9   46.391449   -0.026232        0.004025        0.027481  0.075048
# 10  44.926966    0.092218        0.159065        0.002138  0.074844
# 11  63.339136   -0.028890        0.001413        0.032658  0.071402
# 12  34.191404    0.011318        0.042361        0.018755  0.070793
# 13  75.513267   -0.028128        0.009485        0.046443  0.067473
# 14  58.969277   -0.000000        0.054518        0.002692  0.067121
# 15  71.191935   -0.019687        0.021370        0.023894  0.064906
# 16  22.593830    0.005664        0.037762        0.008754  0.064135
# 17  56.538869   -0.128776        0.001036        0.189194  0.063359
# 18  52.433762   -0.061621        0.011294        0.063008  0.062900
# 19  84.960998    0.161441        0.244121        0.019037  0.060314
# 20  67.992648   -0.053029        0.005946        0.063796  0.059621
# 21  40.101608   -0.030063        0.044102        0.038150  0.059899
# 22  34.579695    1.000000        0.008496        0.002203  0.060683

# %%
consolidation_coin_idx = 5

found_consolidation_coin = False
while found_consolidation_coin == False:
    consolidation_coin = volatile_df.iloc[consolidation_coin_idx]['s'][:-4]
    print(f'Currently checking gor coin {coin}')
    if volatile_df.iloc[consolidation_coin_idx]['Volatility'] < 5:
        coin = consolidation_coin
        df=dataextract(coin,str_date,end_str,timeframe,client)
        super_df=supertrend(coin,df, period,atr1)
        trade_df=create_signal_df(super_df,df,coin,timeframe,atr1,period,100,100)
        found_consolidation_coin = True
    else:
        consolidation_coin -= 1
# Out:
# Currently checking gor coin ENJ
# Gathering ENJ_1h.csv
# Retrived 250 candlestick data

# %%
trade_df.columns
# Out:
# Index(['signal', 'entry', 'tp', 'trade', 'close_price', 'TradeOpenTime',
#        'percentage', 'OpenTime', 'hour', 'minute', 'day', 'month', 'size',
#        'ma_7', 'ma_25', 'ma_99', 'ma_100', 'ma_200', 'ema_81', 'ema_100',
#        'ema_100', 'ema_200', 'ema_55', 'ema_5', 'ema_10', 'ema_20', 'ema_33',
#        'rsi', 'macd', 'macdsignal', 'macdhist', 'slowk', 'slowd',
#        'candle_count', 'local_max', 'local_min', 'local_max_bar',
#        'local_min_bar', 'upper_band', 'lower_band', 'max_log_return',
#        'min_log_return', 'prev_max_log_return', 'prev_min_log_return',
#        'prev_local_max_bar', 'prev_local_min_bar', 'prev_percentage'],
#       dtype='object')

# %%
trade_df[main_columns]
# Out:
#          TradeOpenTime signal   entry trade        rsi      slowk  percentage  \
# 2  2023-08-10 16:00:00   Sell  0.2895     L  48.016321  22.555157   -0.001382
# 3  2023-08-11 00:00:00    Buy  0.2899     L  51.011960  32.142857   -0.007244
# 4  2023-08-11 11:00:00   Sell  0.2878     W  38.115003  21.264368    0.002432
# 5  2023-08-11 16:00:00    Buy  0.2871     W  41.118291  31.299332    0.009404
# 6  2023-08-12 13:00:00   Sell  0.2898     L  49.673739  26.470588   -0.002415
# 7  2023-08-12 18:00:00    Buy  0.2905     L  54.836736  54.711955   -0.004131
# 8  2023-08-13 01:00:00   Sell  0.2893     L  45.565416  32.000000   -0.008296
# 9  2023-08-13 04:00:00    Buy  0.2917     W  60.324332  67.207559    0.007199
# 10 2023-08-13 17:00:00   Sell  0.2938     W  58.717382  60.985562    0.003744
# 11 2023-08-14 01:00:00    Buy  0.2927     L  54.564736  83.581560   -0.003416
# 12 2023-08-14 11:00:00   Sell  0.2917     W  44.736282  36.228683    0.007885
# 13 2023-08-14 17:00:00    Buy  0.2894     L  41.192018  37.113468   -0.002764
# 14 2023-08-15 00:00:00   Sell  0.2886     L  38.778758  11.754313   -0.000000
# 15 2023-08-15 06:00:00    Buy  0.2886     L  45.262990  70.663440   -0.009702
# 16 2023-08-15 08:00:00   Sell  0.2858     L  35.358980  36.469622   -0.007348
# 17 2023-08-15 10:00:00    Buy  0.2879     L  46.361002  28.242894   -0.015283
# 18 2023-08-15 14:00:00   Sell  0.2835     W  33.054655  37.063379    0.022575
# 19 2023-08-15 17:00:00    Buy  0.2771     L  28.687037  54.723863   -0.014074
# 20 2023-08-16 01:00:00   Sell  0.2732     W  29.817592  33.796610    0.037335
# 21 2023-08-16 19:00:00    Buy  0.2630     L  36.166329  43.252606   -0.010646
# 22 2023-08-17 09:00:00   Sell  0.2602     L  35.552385  26.711712   -0.000000
# 23 2023-08-17 13:00:00    Buy  0.2602     L  43.215096  49.624681   -0.013067
# 24 2023-08-17 16:00:00   Sell  0.2568     W  36.508195  72.698413    0.063863
# 25 2023-08-17 20:00:00    Buy  0.2404     L  32.836391  53.864968   -1.000000
#
#     max_log_return  min_log_return    ema_81  upper_band  lower_band
# 2         0.005181        0.004491       NaN    0.291529    0.288571
# 3         0.010003        0.010003       NaN    0.290536    0.288064
# 4         0.010076        0.002432       NaN    0.290664    0.287336
# 5         0.020550        0.001393       NaN    0.288686    0.285314
# 6         0.004831        0.002761  0.289568    0.291693    0.289007
# 7         0.004131        0.006196  0.289544    0.291614    0.288986
# 8         0.001037        0.008642  0.289664    0.290543    0.288357
# 9         0.018512        0.003771  0.289730    0.291886    0.289614
# 10        0.019061        0.001702  0.290705    0.295971    0.292629
# 11        0.010591        0.004783  0.290831    0.294021    0.290079
# 12        0.018512        0.002400  0.291431    0.294650    0.291450
# 13        0.005529        0.003110  0.291133    0.290586    0.287214
# 14        0.010395        0.000347  0.290901    0.290550    0.287350
# 15        0.000347        0.010049  0.290427    0.289093    0.286307
# 16        0.004899        0.008048  0.290228    0.288057    0.285043
# 17        0.000695        0.019104  0.290059    0.287971    0.284529
# 18        0.075485        0.000353  0.289623    0.286236    0.282264
# 19        0.006496        0.014796  0.288628    0.279593    0.272707
# 20        0.070644        0.001464  0.286289    0.278407    0.270893
# 21        0.008745        0.026236  0.279123    0.264450    0.257150
# 22        0.030361        0.004228  0.274239    0.263114    0.258486
# 23        0.001922        0.020369  0.272684    0.261736    0.256064
# 24        0.170950        0.002726  0.271675    0.260329    0.254271
# 25        0.020383        0.012063  0.268359    0.246500    0.232000

# %%
volatile_df.iloc[4]['s']
# Out:
# 'XTZUSDT'
